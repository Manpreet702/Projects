# %%
# !python -m coverage run TestSuite.py
# Out:
# DEBUG: Data path found and added successfully.
# DEBUG: Successfully imported DBManager class.
# DEBUG: Logic path added successfully.
# DEBUG: Successfully imported stats module.
# MySQL connection closed.
# Error connecting to MySQL: Connection failed
# Successfully connected to MySQL Database.
# Error fetching exercises: Query failed
#
# Testing valid input execution...
# DEBUG: Function executed successfully.
# test_close_connection (ConnectTest.TestDBConnection.test_close_connection)
# Test close() method. ... ok
# test_close_no_connection (ConnectTest.TestDBConnection.test_close_no_connection)
# Test close() when no connection exists. ... ok
# test_connect_failure (ConnectTest.TestDBConnection.test_connect_failure)
# Test connection failure. ... ok
# test_connect_success (ConnectTest.TestDBConnection.test_connect_success)
# Test successful connection. ... ok
# test_fetch_all_exercises_db_error (ConnectTest.TestDBConnection.test_fetch_all_exercises_db_error)
# ...

# %%
# !python -m coverage html
# Out:
# Wrote HTML report to htmlcov\index.html
