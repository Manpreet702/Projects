# %%
import unittest

from ConnectTest import TestDBConnection
from DrawTest import TestStatsVisualization
from RecheckTest import TestStatsValidation

suite = unittest.TestSuite()

loader = unittest.TestLoader()
suite.addTests(loader.loadTestsFromTestCase(TestDBConnection))
suite.addTests(loader.loadTestsFromTestCase(TestDBFetching))
suite.addTests(loader.loadTestsFromTestCase(TestStatsValidation))

runner = unittest.TextTestRunner(verbosity=2)
runner.run(suite)
# Out:
# test_connect_failure (ConnectTest.TestDBConnection.test_connect_failure)
# okst 2: Connection failure path. ...
# test_connect_success (ConnectTest.TestDBConnection.test_connect_success)
# okst 1: Connection success path. ...
# test_fetch_exercises (__main__.TestDBFetching.test_fetch_exercises)
# okst 1: Fetching exercises (Raw List). ...
# test_fetch_stats (__main__.TestDBFetching.test_fetch_stats)
# okst 2: Fetching user stats. ...
# test_empty_input (RecheckTest.TestStatsValidation.test_empty_input)
# okst 2: Empty data should print error and return. ...
# test_valid_input (RecheckTest.TestStatsValidation.test_valid_input)
# okst 1: Valid data should trigger plotting. ...
#
# ----------------------------------------------------------------------
# Ran 6 tests in 0.175s
#
# OK
# Error connecting to MySQL: Fail
# Successfully connected to MySQL Database.
#
# Motivation Check: You are not in your mood.
# <unittest.runner.TextTestResult run=6 errors=0 failures=0>

# %%
# Out:
# 📍 当前工作目录: C:\Users\liu zihuan\gym_track_app\gymtrack\test
# 📂 发现的 .py 文件: []
